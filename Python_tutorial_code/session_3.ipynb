# %%
var_1 = "words" # string
var_2 = 10 # integer
var_3 = 10.0 # float
var_4 = [10, 10.0, "10", var_3, [var_1, var_2]] # list
var_5 = {"key_1":var_1,
         "key_2":var_4}  # dictionary

var_5["key_3"] = "value 3"

print(var_5["key_1"])
print(var_5.items())
print(var_5.keys())
print(var_5.values())
# Out:
# words
# dict_items([('key_1', 'words'), ('key_2', [10, 10.0, '10', 10.0, ['words', 10]]), ('key_3', 'value 3')])
# dict_keys(['key_1', 'key_2', 'key_3'])
# dict_values(['words', [10, 10.0, '10', 10.0, ['words', 10]], 'value 3'])

# %%
# pandas
import pandas as pd # importing pandas with the alias pd
import os # allows you to use filepaths on your operating system

# filepath = "c://shared_drive_name/path_to_file/file_name.csv" # examples for reading files into Python


filepath = r"https://raw.githubusercontent.com/data-to-insight/ERN-sessions/main/data/1980%202023%20average%20house%20prices.csv"

house_prices = pd.read_csv(filepath) # pd.read_excel() for reading excels

type(house_prices) # dataframe pands word for tabular data

# house_prices.info()

# house_prices.head(20)

# house_prices.tail(10)
# Out:
# pandas.core.frame.DataFrame

# %%
 
# pandas
import pandas as pd # importing pandas with the alias pd

filepath = r"https://raw.githubusercontent.com/data-to-insight/ERN-sessions/main/data/ChildIdentifiers.csv"
ci = pd.read_csv(filepath) # pd.read_excel() for reading excels
type(ci) # DataFrame pandas word for tabular data
# standard variable name for dataframes df
# child_data.info() # gives table info
# child_data.head(20) # top rows
# child_data.tail(10)  # bottom rows
#print(child_data)

ci.tail()
# Out:
#      Unnamed: 0        LAchildID            UPN  FormerUPN  UPNunknown  \
# 327         327  RND000112711501  A465246916125        NaN         NaN
# 328         328  RND000513120794  A540014111973        NaN         NaN
# 329         329  RND000541643134  A549582689058        NaN         NaN
# 330         330  RND000404939452  A889492349196        NaN         NaN
# 331         331  RND000589802835  A877624860226        NaN         NaN
#
#     PersonBirthDate ExpectedPersonBirthDate  GenderCurrent PersonDeathDate
# 327      2010-07-07                     NaN              2             NaN
# 328      2018-08-14                     NaN              2             NaN
# 329      2021-12-09                     NaN             51             NaN
# 330      2013-07-23                     NaN              2             NaN
# 331      2021-10-25                     NaN              9             NaN

# %%
# house_prices["Period_dt"] = pd.to_datetime(house_prices["Period"], format = "%Y-"m")
                                           
house_prices["Period_dt"] = pd.to_datetime(house_prices["Period"], format="%Y-%m")

house_prices["Period_dt"].info() # check type has changed


# datetime /datatime object

# 02/01/2025 - america 1 feb, uk 2 jan

house_prices["Period_dt"]
# 01/01/2025 %d/%m%Y
# 01/01/25 %d/%m/%y

# 30-12-2025 %d-%m-%Y
# 30122025 %d%m%Y
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 523 entries, 0 to 522
# Series name: Period_dt
# Non-Null Count  Dtype
# --------------  -----
# 523 non-null    datetime64[ns]
# dtypes: datetime64[ns](1)
# memory usage: 4.2 KB
# 0     1980-01-01
# 1     1980-02-01
# 2     1980-03-01
# 3     1980-04-01
# 4     1980-05-01
#          ...
# 518   2023-03-01
# 519   2023-04-01
# 520   2023-05-01
# 521   2023-06-01
# 522   2023-07-01
# Name: Period_dt, Length: 523, dtype: datetime64[ns]

# %%
ci

ci["PersonBirthDate_dt"] = pd.to_datetime(ci["PersonBirthDate"], format="%Y-%m-%d")
ci["ExpectedPersonBirthDate_dt"] = pd.to_datetime(ci["ExpectedPersonBirthDate"], format="%Y-%m-%d")

ci["PersonDeathDate_dt"] = pd.to_datetime(ci["PersonDeathDate"], format="%Y-%m-%d", errors="coerce")

ci
# Out:
#      Unnamed: 0        LAchildID            UPN  FormerUPN  UPNunknown  \
# 0             0  RND000215205141  A850728973744        NaN         NaN
# 1             1  RND000824303014  A141396438491        NaN         NaN
# 2             2  RND000750143123  A929946861554        NaN         NaN
# 3             3  RND000909164501  A612330267292        NaN         NaN
# 4             4  RND000382171815  A604459366806        NaN         NaN
# ..          ...              ...            ...        ...         ...
# 327         327  RND000112711501  A465246916125        NaN         NaN
# 328         328  RND000513120794  A540014111973        NaN         NaN
# 329         329  RND000541643134  A549582689058        NaN         NaN
# 330         330  RND000404939452  A889492349196        NaN         NaN
# 331         331  RND000589802835  A877624860226        NaN         NaN
#
#     PersonBirthDate ExpectedPersonBirthDate  GenderCurrent PersonDeathDate  \
# 0        2019-12-06                     NaN              1             NaN
# 1        2011-04-27                     NaN              9             NaN
# 2        2017-06-06              2019-12-06              1             NaN
# 3        2014-10-03                     NaN              0             NaN
# 4        2019-09-25                     NaN              2             NaN
# ..              ...                     ...            ...             ...
# 327      2010-07-07                     NaN              2             NaN
# 328      2018-08-14                     NaN              2             NaN
# 329      2021-12-09                     NaN             51             NaN
# 330      2013-07-23                     NaN              2             NaN
# 331      2021-10-25                     NaN              9             NaN
#
#     PersonBirthDate_dt ExpectedPersonBirthDate_dt PersonDeathDate_dt
# 0           2019-12-06                        NaT                NaT
# 1           2011-04-27                        NaT                NaT
# 2           2017-06-06                 2019-12-06                NaT
# 3           2014-10-03                        NaT                NaT
# 4           2019-09-25                        NaT                NaT
# ..                 ...                        ...                ...
# 327         2010-07-07                        NaT                NaT
# 328         2018-08-14                        NaT                NaT
# 329         2021-12-09                        NaT                NaT
# 330         2013-07-23                        NaT                NaT
# 331         2021-10-25                        NaT                NaT
#
# [332 rows x 12 columns]

# %%
ci["PersonBirthDate_dt"] = pd.to_datetime(ci["PersonBirthDate"], format="%Y-%m-%d")
ci["ExpectedPersonBirthDate_dt"] = pd.to_datetime(ci["ExpectedPersonBirthDate"], format="%Y-%m-%d")

ci["PersonDeathDate_dt"] = pd.to_datetime(ci["PersonDeathDate"], format="%Y-%m-%d", errors="coerce")

# %%
#max, min, median, mean, sum

max_change = house_prices["Percentage change (monthly) All property types"].max()
min_change = house_prices["Percentage change (monthly) All property types"].min()
sum_change = house_prices["Percentage change (monthly) All property types"].sum()

print(max_change)
print(min_change)
print(f"Max change: {max_change}, min change: {min_change}")

median_price = house_prices["Average price All property types"].median()
mean_price = house_prices["Average price All property types"].mean()


print(median_price)
print(mean_price)
print(sum_change)

condition = house_prices["Average price All property types"]<mean_price

less_than_mean = house_prices[condition]

less_than_mean
# Out:
# 13.29
# -4.79
# Max change: 13.29, min change: -4.79
# 97964.0
# 120570.55831739961
# 623.29
#                Name   Period  House price index All property types  \
# 0    United Kingdom  1980-01                                 10.11
# 1    United Kingdom  1980-02                                 10.11
# 2    United Kingdom  1980-03                                 10.11
# 3    United Kingdom  1980-04                                 10.51
# 4    United Kingdom  1980-05                                 10.51
# ..              ...      ...                                   ...
# 269  United Kingdom  2002-06                                 59.43
# 270  United Kingdom  2002-07                                 59.90
# 271  United Kingdom  2002-08                                 61.23
# 272  United Kingdom  2002-09                                 62.72
# 273  United Kingdom  2002-10                                 63.19
#
#      Average price All property types  \
# 0                               19273
# 1                               19273
# 2                               19273
# 3                               20044
# 4                               20044
# ..                                ...
# 269                            113304
# 270                            114214
# 271                            116743
# 272                            119576
# 273                            120486
#
#      Percentage change (monthly) All property types  \
# 0                                              3.94
# 1                                              3.94
# 2                                              3.94
# 3                                              4.00
# 4                                              4.00
# ..                                              ...
# 269                                            4.09
# 270                                            0.80
# 271                                            2.21
# 272                                            2.43
# 273                                            0.76
#
#      Percentage change (yearly) All property types  Period_dt
# 0                                            28.59 1980-01-01
# 1                                            28.59 1980-02-01
# 2                                            28.59 1980-03-01
# 3                                            24.15 1980-04-01
# 4                                            24.15 1980-05-01
# ..                                             ...        ...
# 269                                          17.41 2002-06-01
# 270                                          14.25 2002-07-01
# 271                                          16.78 2002-08-01
# 272                                          19.61 2002-09-01
# 273                                          22.99 2002-10-01
#
# [274 rows x 7 columns]

# %%
#age is current date - date

# current_date = pd.to_datetime("today")


collection_end = pd.to_datetime("31/03/2025", format="%d/%m/%y")

ci["time_delta"] = collection_end - ci["PersonBirthDate_dt"]

ci['Age'] = ci["time_delta"] / pd.Timedelta(365.25,"d")

ci['Age'] - ci["Age"].astype(int)

ci['Age']

# current_date
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[79], line 6
#       1 #age is current date - date
#       2
#       3 # current_date = pd.to_datetime("today")
# ----> 6 collection_end = pd.to_datetime("31/03/2025", format="%d/%m/%y")
#       8 ci["time_delta"] = collection_end - ci["PersonBirthDate_dt"]
#      10 ci['Age'] = ci["time_delta"] / pd.Timedelta(365.25,"d")
#
# File ~/.local/lib/python3.12/site-packages/pandas/core/tools/datetimes.py:1106, in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, infer_datetime_format, origin, cache)
#    1104         result = convert_listlike(argc, format)
#    1105 else:
# -> 1106     result = convert_listlike(np.array([arg]), format)[0]
#    1107     if isinstance(arg, bool) and isinstance(result, np.bool_):
#    1108         result = bool(result)  # TODO: avoid this kludge.
#
# File ~/.local/lib/python3.12/site-packages/pandas/core/tools/datetimes.py:435, in _convert_listlike_datetimes(arg, format, name, utc, unit, errors, dayfirst, yearfirst, exact)
#     433 # `format` could be inferred, or user didn't ask for mixed-format parsing.
#     434 if format is not None and format != "mixed":
# --> 435     return _array_strptime_with_fallback(arg, name, utc, format, exact, errors)
#     437 result, tz_parsed = objects_to_datetime64(
#     438     arg,
#     439     dayfirst=dayfirst,
#    (...)    443     allow_object=True,
#     444 )
#     446 if tz_parsed is not None:
#     447     # We can take a shortcut since the datetime64 numpy array
#     448     # is in UTC
#
# File ~/.local/lib/python3.12/site-packages/pandas/core/tools/datetimes.py:469, in _array_strptime_with_fallback(arg, name, utc, fmt, exact, errors)
#     458 def _array_strptime_with_fallback(
#     459     arg,
#     460     name,
#    (...)    464     errors: str,
#     465 ) -> Index:
#     466     """
#     467     Call array_strptime, with fallback behavior depending on 'errors'.
#     468     """
# --> 469     result, tz_out = array_strptime(arg, fmt, exact=exact, errors=errors, utc=utc)
#     470     if tz_out is not None:
#     471         unit = np.datetime_data(result.dtype)[0]
#
# File pandas/_libs/tslibs/strptime.pyx:501, in pandas._libs.tslibs.strptime.array_strptime()
#
# File pandas/_libs/tslibs/strptime.pyx:451, in pandas._libs.tslibs.strptime.array_strptime()
#
# File pandas/_libs/tslibs/strptime.pyx:587, in pandas._libs.tslibs.strptime._parse_with_format()
#
# ValueError: unconverted data remains when parsing with format "%d/%m/%y": "25", at position 0. You might want to try:
#     - passing `format` if your strings have a consistent format;
#     - passing `format='ISO8601'` if your strings are all ISO8601 but not necessarily in exactly the same format;
#     - passing `format='mixed'`, and the format will be inferred for each element individually. You might want to use `dayfirst` alongside this.
